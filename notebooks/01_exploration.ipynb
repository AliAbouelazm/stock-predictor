# %% [markdown]
# # stockly - Data Exploration
#
# Exploratory data analysis of stock price data and features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys

sys.path.append(str(Path().resolve().parent))

from src.database.db_utils import get_connection, query_features_and_targets
from src.config import DB_PATH

# %%
conn = get_connection()
df = query_features_and_targets(conn)
conn.close()

print(f"Dataset shape: {df.shape}")
print(f"Date range: {df['date'].min()} to {df['date'].max()}")
df.head()

# %%
print("Direction label distribution:")
print(df['direction_label'].value_counts())
print("\nPercentages:")
print(df['direction_label'].value_counts(normalize=True) * 100)
